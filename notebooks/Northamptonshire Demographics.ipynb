# %% [markdown]
# # Northamptonshire Census Data

# %% [markdown]
# ## Experiments with Demographic Data

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from analysis.datafetch.northants import DataFetcher

# %%
fd = DataFetcher()
fd.load_metadata('../analysis/datafetch/metadata.json')

# %%
dataviews = fd.get_dataview_ids_with_details()
dvdf = pd.DataFrame(dataviews).transpose().sort(['theme'])
dvdf
# Out:
#                                            description  \
# 199  Residents who provide unpaid care to others by...
# 54   Live Births, Fertility Rates, Infant Mortality...
# 112
# 114
# 115
# 163  Results of the Departments of Health and Educa...
# 191  % of all Foundation Stage pupils in schools (a...
# 192  % of those deemed "End of Key Stage 4" who ach...
# 211  Young people (Under Age 24) claiming Job Seeke...
# 230  Children in Low Income Families Local Measure ...
# 250  Characteristics of Young People 10-17 who offe...
# 251  Outcomes/Disposals received by a young person ...
# 252  Outcomes/Disposals received by a young person ...
# 253  Outcomes/Disposals received by a young person ...
# 254  Outcomes/Disposals received by a young person ...
# 255  Outcomes/Disposals received by a young person ...
# 256  Outcomes/Disposals received by a young female ...
# 257  Outcomes/Disposals received by a young male pe...
# 258  % of young people receiving the four main cate...
# ...

# %%
fp1 = fd.fetch_dataview_csv(54, 'county')
fp2 = fd.fetch_dataview_csv(54, 'district')
fp3 = fd.fetch_dataview_csv(54, 'region')

infant_mortality_county = pd.read_csv(fp1)
infant_mortality_district = pd.read_csv(fp2)
infant_mortality_region = pd.read_csv(fp3)
infant_mortality_district
# Out:
#   ﻿"District "                    Name  Live Births : Total(2005)  \
# 0         34UB                   Corby                        674
# 1         34UC                Daventry                        856
# 2         34UD   East Northamptonshire                        945
# 3         34UE               Kettering                       1156
# 4         34UF             Northampton                       2825
# 5         34UG  South Northamptonshire                        882
# 6         34UH          Wellingborough                        930
# 7           34        Northamptonshire                       8268
# 8            E           East Midlands                        NaN
# 9          064                 England                        NaN
#
#    Live Births : Total(2006)  Live Births : Total(2007)  \
# 0                        745                        803
# 1                        864                        823
# 2                        976                       1040
# ...
