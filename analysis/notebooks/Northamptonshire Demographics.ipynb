# %% [markdown]
# # Northamptonshire Census Data

# %% [markdown]
# ## Experiments with Demographic Data

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
geo_ids = {
    'county' : 28,
    'district' : 46,
    'electoral_division_post_2013' : 67,
    'lsoa' : 58,
    'community_safety_partnership' : 76,
    'ccg_locality' : 49,
    'region' : 22,
}

theme_ids = {
    'Adult Social Care' : 43,
    
}

# %%
df = pd.read_csv('data/dataView151_28.csv')

# %%
df
# Out:
#   ﻿"County"              Name  \
# 0        34  Northamptonshire
# 1         E     East Midlands
# 2       064           England
#
#    Total Resident Population : Persons All Ages Total(2011)  \
# 0                                             691952
# 1                                            4533222
# 2                                           53012456
#
#    Total Resident Population : Persons All Ages Total(2012)  \
# 0                                             700576
# 1                                            4567731
# 2                                           53493729
#
#    DifferenceCYrvCensus2011 PercentDiffCYrvCensus2011  \
# 0                      8624                      1.2%
# 1                     34509                      0.8%
# 2                    481273                      0.9%
#
#   ChangeDescCYrvCensus2011  \
# 0                 increase
# 1                 increase
# 2                 increase
#
# ...

# %%
fig = plt.figure()
df[['Name', 'Total Resident Population : Persons All Ages Total(2011)']].plot(kind="bar", axes=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1b7a2ea2f8b4> in <module>()
#       1 fig = plt.figure()
# ----> 2 axes = fig.add_axes(df['Name']) # left, bottom, width, height (range 0 to 1)
#       3 axes.plot(df['Name'], df['Total Resident Population : Persons All Ages Total(2011)'], 'r')
#
# /home/anshuman/virt_env/northants/local/lib/python2.7/site-packages/matplotlib/figure.pyc in add_axes(self, *args, **kwargs)
#     872
#     873             # create the new axes using the axes class given
# --> 874             a = projection_class(self, rect, **kwargs)
#     875
#     876         self._axstack.add(key, a)
#
# /home/anshuman/virt_env/northants/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     392             self._position = rect
# ...
